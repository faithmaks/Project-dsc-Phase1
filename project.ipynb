# %% [markdown]
# ### This Project needs Data Exploration

# %% [markdown]
# Start by importing the libraries

# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Loading the data

# %%
# LOADING THE DATA
The_movie_db_movies=pd.read_csv ('tmdb.movies.csv')
The_numbers_movie_budgets=pd.read_csv ('tn.movie_budgets.csv')
Box_office_movie_gross=pd.read_csv('bom.movie_gross.csv')
Rotten_tomatoes= pd.read_csv('rt.movie_info.csv')
IMDB= sqlite3.connect('im.db')

# %% [markdown]
# Exploring What Each Data Set Looks like

# %%
# MOVIE DB
The_movie_db_movies
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
# The Numbers- Movie Budgets
The_numbers_movie_budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
type(The_movie_db_movies)
# Out:
# pandas.core.frame.DataFrame

# %%
# Box Office Movie Gross
Box_office_movie_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
Box_office_movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
# Rotten Tomatoes 
Rotten_tomatoes
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %%
Rotten_tomatoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
#IMDB
pd.read_sql("""
SELECT *
FROM movie_basics;
""", IMDB)
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
pd.read_sql("""
SELECT *
FROM movie_ratings
;
""", IMDB)
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
#GenScore=Rotten_tomatoes.set_index('id').join(Box_office_movie_gross, how= 'inner',)

# %% [markdown]
# ### Cleaning the Data

# %% [markdown]
# Checking for missing values

# %%
#identifying missing values
def missing_values(data):
    missing_val = data.isnull().sum().sort_values(ascending = False)

    return missing_val

# %%
missing_values(Box_office_movie_gross)
# Out:
# foreign_gross     1350
# domestic_gross      28
# studio               5
# year                 0
# title                0
# dtype: int64

# %%
missing_values(The_numbers_movie_budgets)
# Out:
# worldwide_gross      0
# domestic_gross       0
# production_budget    0
# movie                0
# release_date         0
# id                   0
# dtype: int64

# %%
missing_values(Rotten_tomatoes)
# Out:
# box_office      1220
# currency        1220
# studio          1066
# writer           449
# dvd_date         359
# theater_date     359
# director         199
# synopsis          62
# runtime           30
# genre              8
# rating             3
# id                 0
# dtype: int64

# %% [markdown]
# Checking for Duplicates

# %%
The_numbers_movie_budgets.duplicated().value_counts()
# Out:
# False    5782
# dtype: int64

# %%
Box_office_movie_gross.duplicated().value_counts()
# Out:
# False    3387
# dtype: int64

# %%
Rotten_tomatoes.duplicated().value_counts()
# Out:
# False    1560
# dtype: int64

# %% [markdown]
# ### Data Analysis

# %%
pd.read_sql("""
SELECT *
 FROM movie_basics
 ;

""", IMDB)
#  JOIN movie_ratings
#  USING movie_basics.movie_id == movie_ratings.movie_id
#  ORDER BY averagerating
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
Movie_ratings_IMDB= pd.read_sql("""
SELECT *
FROM movie_basics AS b
LEFT JOIN movie_ratings AS r
ON b.movie_id = r.movie_id
ORDER BY averagerating DESC
LIMIT 1000
;
""", IMDB)

# %%
Movie_ratings_IMDB
# Out:
#        movie_id                                   primary_title  \
# 0    tt10176328  Exteriores: Mulheres Brasileiras na Diplomacia
# 1    tt10378660       The Dark Knight: The Ballad of the N Word
# 2     tt1770682                            Freeing Bernie Baran
# 3     tt2632430                           Hercule contre Hermès
# 4     tt4109192                           I Was Born Yesterday!
# ..          ...                                             ...
# 995   tt9426254                              Savasin Efsaneleri
# 996   tt9476068                              Her Mind in Pieces
# 997   tt9581518                                   Dearest Anita
# 998   tt9811598                                           Chaos
# 999   tt9855510                                         Oildale
#
#                                      original_title  start_year  \
# 0    Exteriores: Mulheres Brasileiras na Diplomacia        2018
# 1         The Dark Knight: The Ballad of the N Word        2018
# ...

# %%
Movie_ratings_IMDB.describe()
# Out:
#         start_year  runtime_minutes  averagerating       numvotes
# count  1000.000000       840.000000    1000.000000    1000.000000
# mean   2015.275000        83.688095       9.255700     268.240000
# std       2.642415        36.857104       0.180222    3560.505217
# min    2010.000000         4.000000       9.100000       5.000000
# 25%    2013.000000        62.000000       9.100000       7.000000
# 50%    2016.000000        82.000000       9.200000      14.000000
# 75%    2017.000000        95.000000       9.300000      34.000000
# max    2019.000000       607.000000      10.000000  100568.000000

# %%
# Best rated genres on IMDB
Movie_ratings_IMDB['genres'].value_counts().head(15)
# Out:
# Documentary                      427
# Drama                            125
# Comedy                            25
# Documentary,Music                 21
# Documentary,Sport                 20
# Documentary,History               20
# Documentary,Drama                 19
# Biography,Documentary,Drama       17
# Biography,Documentary             13
# Music                             12
# Biography,Documentary,History     11
# Biography,Comedy,Documentary      11
# Biography,Documentary,Music       11
# Comedy,Drama                      10
# Family                             9
# Name: genres, dtype: int64

# %%
#turning to a dataframe
from re import I


r= Movie_ratings_IMDB['genres'].value_counts().head(15)
IMDB_Best_Rated_Genres=pd.DataFrame(r)
IMDB_Best_Rated_Genres=IMDB_Best_Rated_Genres.reset_index()
IMDB_Best_Rated_Genres.columns=['Genre', 'counts']
IMDB_Best_Rated_Genres
# Out:
#                             Genre  counts
# 0                     Documentary     427
# 1                           Drama     125
# 2                          Comedy      25
# 3               Documentary,Music      21
# 4               Documentary,Sport      20
# 5             Documentary,History      20
# 6               Documentary,Drama      19
# 7     Biography,Documentary,Drama      17
# 8           Biography,Documentary      13
# 9                           Music      12
# 10  Biography,Documentary,History      11
# 11   Biography,Comedy,Documentary      11
# 12    Biography,Documentary,Music      11
# 13                   Comedy,Drama      10
# 14                         Family       9

# %%
r.plot.barh(title='IMDB TOP 15 GENRES', color='orange');

# %%
# Best Performing  Box Office Movies foreign vs domestic

# %%
joined_df = df1.join(df2, how='inner')

# %% [markdown]
# ### Ratings
# For ratings in Box Office, I shall use Rotten Tomatoes

# %%
Rotten_tomatoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
Rotten_tomatoes['director'].value_counts().head(10)
# Out:
# Steven Spielberg    10
# Clint Eastwood       8
# William Beaudine     4
# Curtis Hanson        4
# Ridley Scott         4
# William Friedkin     4
# Barry Levinson       4
# Woody Allen          4
# Yimou Zhang          4
# Alfred Hitchcock     4
# Name: director, dtype: int64

# %%
Rotten_tomatoes['studio'].value_counts().head(10)
# Out:
# Universal Pictures        35
# Paramount Pictures        27
# 20th Century Fox          26
# Sony Pictures Classics    22
# Warner Bros. Pictures     21
# Sony Pictures             16
# Columbia Pictures         10
# New Line Cinema           10
# IFC Films                  9
# Miramax Films              8
# Name: studio, dtype: int64

# %%
Rotten_tomatoes['genre'].value_counts().head(10)
# Out:
# Drama                                              151
# Comedy                                             110
# Comedy|Drama                                        80
# Drama|Mystery and Suspense                          67
# Art House and International|Drama                   62
# Action and Adventure|Drama                          42
# Action and Adventure|Drama|Mystery and Suspense     40
# Drama|Romance                                       35
# Comedy|Romance                                      32
# Art House and International|Comedy|Drama            31
# Name: genre, dtype: int64

# %%
Rotten_tomatoes['writer'].value_counts().head(10)
# Out:
# Woody Allen           4
# Sylvester Stallone    3
# John Hughes           3
# Hong Sang-soo         3
# Jim Jarmusch          3
# Ingmar Bergman        2
# William Goldman       2
# Mike White            2
# David Mamet           2
# Clair Huffaker        2
# Name: writer, dtype: int64

# %%
(Rotten_tomatoes['writer'].value_counts().head(10)).plot.barh(title='Best_Rt_rated _writers');

# %%
The_movie_db_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
The_movie_db_movies

# %%
The_movie_db_movies['g'].value_counts().head(10)
# Out:
# [99]           3700
# []             2479
# [18]           2268
# [35]           1660
# [27]           1145
# [53]            480
# [35, 18]        466
# [10402]         399
# [27, 53]        378
# [18, 10749]     352
# Name: genre_ids, dtype: int64

# %% [markdown]
# ### Budgeting
# I shall use The Numbers Data and

# %%
The_numbers_movie_budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
b=The_numbers_movie_budgets.head(10)
b
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# 5   6  Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
# 6   7  Apr 27, 2018                       Avengers: Infinity War
# 7   8  May 24, 2007   Pirates of the Caribbean: At Worldâs End
# 8   9  Nov 17, 2017                               Justice League
# 9  10   Nov 6, 2015                                      Spectre
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# ...

# %%
from turtle import title


k = b['production_budget']	#red
m= b['domestic_gross']	#green
n= b['worldwide_gross'] #blue
r=np.arange(0, 10, 1)
plt.figure(figsize=(10,10), )
plt.plot(r, k,'r--', r, m,'g--', r, n,'b--')
plt.title('Production budget against gross',fontsize = 14, fontweight ='bold')
plt.show()

# %%
#   # the width of the bars
# x= b['movie']

# fig, ax = plt.subplots(figsize=(18,10))
# rects1= ax.bar(x, b['production_budget'], label='Production')
# rects2= ax.bar(x , b['domestic_gross'], label= 'domestic') 
# rects3= ax.bar(x, b['worldwide_gross'], label= 'international')
# # Add some text for labels, title and custom x-axis tick labels, etc.
# ax.set_ylabel('Amount')
# ax.set_title('Movie Budgets')
# ax.set_xticks=( x)
# ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)
# ax.bar_label(rects3, padding=3)

# fig.tight_layout()

# plt.show()

# %%
b.plot.bar(stacked=True);

# %%
Box_office_movie_gross.tail(20)
# Out:
#                                                   title      studio  \
# 3367                      Elliot: The Littlest Reindeer       Scre.
# 3368                                       The Workshop      Strand
# 3369                                       Loving Pablo        Uni.
# 3370                                  A Paris Education          KL
# 3371                          Tag Along: The Devil Fish          CL
# 3372                           Gabriel and the Mountain      Strand
# 3373                  Marlina the Murderer in Four Acts       Icar.
# 3374                                         The Escape         IFC
# 3375  How Victor 'The Garlic' Took Alexey 'The Stud'...     CARUSEL
# 3376        Lou Andreas-Salomé, the Audacity to be Free         CLS
# 3377                                    Let Yourself Go        Men.
# 3378                                      Hannah (2018)         PDF
# 3379                                           Souvenir      Strand
# ...

# %%
Box_office_movie_gross.head(1000).describe()
# Out:
#        domestic_gross         year
# count    9.880000e+02  1000.000000
# mean     3.145458e+07  2010.945000
# std      6.131724e+07     0.773675
# min      7.000000e+02  2010.000000
# 25%      2.007500e+05  2010.000000
# 50%      3.000000e+06  2011.000000
# 75%      3.750000e+07  2012.000000
# max      6.234000e+08  2012.000000

# %%
Top_100_Box_Office= Box_office_movie_gross.head(100)
Top_100_Box_Office
# Out:
#                                           title studio  domestic_gross  \
# 0                                   Toy Story 3     BV     415000000.0
# 1                    Alice in Wonderland (2010)     BV     334200000.0
# 2   Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                     Inception     WB     292600000.0
# 4                           Shrek Forever After   P/DW     238700000.0
# ..                                          ...    ...             ...
# 95                                  Secretariat     BV      59700000.0
# 96                             The Ghost Writer   Sum.      15500000.0
# 97                                Morning Glory   Par.      31000000.0
# 98                                  Remember Me   Sum.      19100000.0
# 99                                      Cop Out     WB      44900000.0
#
#    foreign_gross  year
# 0      652000000  2010
# 1      691300000  2010
# 2      664300000  2010
# ...

# %%
bEST_GROSSING_BO_STUDIOS=Box_office_movie_gross['studio'].value_counts().head(100)
bEST_GROSSING_BO_STUDIOS.plot.bar(color= 'green', title= 'best studios' )
# Out:
# <AxesSubplot:title={'center':'best studios'}>

# %%
e=Top_100_Box_Office['domestic_gross']
g=Top_100_Box_Office['foreign_gross']
h=Top_100_Box_Office['title'] 
width = 0.35  # the width of the bars
x= b['movie']

fig, ax = plt.subplots(figsize=(18,10))
rects1= ax.bar(h , e, label='domestic')
rects2= ax.bar(h , g, label= 'foreign') 
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Amount')
ax.set_title('Movie Gross')
ax.set_xticks=( h)
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %%
e=Top_100_Box_Office['domestic_gross']
g=Top_100_Box_Office['foreign_gross']
h=Top_100_Box_Office['title'] 

plt.figure(figsize=(10,10))
plt.subplot()
plt.plot(e, h, 'y--', g, h,'g--')
plt.show()

# %%
k= np.arange(0, 100, 1)
plt.figure(figsize=(10,10))
plt.plot(k, e,'r--', k, g, k,'g--')
plt.title('Domestic gross vs Foreign Gross', fontsize = 14, fontweight ='bold')
plt.show()

# %%
studios_dominating_bo=Top_100_Box_Office.studio.value_counts()

# %%
studios_dominating_bo.plot.bar(color= 'green', title= 'studios_dominating_bo' )
;
# Out:
# ''

# %%
#joining two relative tables

# %%
IMDB.close()
